# %% [markdown]
# <a href="https://colab.research.google.com/github/JeriesKawaneh/Prediction-of-Product-Sales/blob/main/Git_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project Title:(predection of Product Sales)
# - Authored by Jeries Kawaneh

# %% [markdown]
# #Project Overview

# %% [markdown]
# #Load and Inspect Data

# %% [markdown]
# #Clean Data

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# #Feature Inspection
